# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !cd /content/drive/MyDrive
# !git clone https://github.com/pjreddie/darknet
#!wget https://pjreddie.com/media/files/val2014.zip -d /content/drive/MyDrive/coco/images/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5940, done.
# remote: Counting objects: 100% (5940/5940), done.
# remote: Compressing objects: 100% (1962/1962), done.
# remote: Total 5940 (delta 3942), reused 5940 (delta 3942), pack-reused 0
# Receiving objects: 100% (5940/5940), 6.34 MiB | 16.40 MiB/s, done.
# Resolving deltas: 100% (3942/3942), done.

# %%
#!cd /content/drive/MyDrive/darknet
#!bash /content/drive/MyDrive/darknet/scripts/get_coco_dataset.sh
#!unzip /content/drive/MyDrive/val2014.zip -d /content/drive/MyDrive/

# %%
# %cd /content/drive/MyDrive/darknet
# !make
# !chmod +x ./darknet
# Out:
# /content/drive/MyDrive/darknet
# mkdir -p backup

# %%
# !rm /content/drive/MyDrive/darknet/backup -r
# !ln -s /content/drive/'My Drive'/YOLOv3_weight/backup /content/darknet

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 2s (221 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/val.txt
# !dos2unix ./data/yolo.data
# !dos2unix ./data/yolo.names
# !dos2unix ./cfg/yolov3_custom_train.cfg
# Out:
# dos2unix: ./data/train.txt: No such file or directory
# dos2unix: Skipping ./data/train.txt, not a regular file.
# dos2unix: ./data/val.txt: No such file or directory
# dos2unix: Skipping ./data/val.txt, not a regular file.
# dos2unix: ./data/yolo.data: No such file or directory
# dos2unix: Skipping ./data/yolo.data, not a regular file.
# dos2unix: ./data/yolo.names: No such file or directory
# dos2unix: Skipping ./data/yolo.names, not a regular file.
# dos2unix: ./cfg/yolov3_custom_train.cfg: No such file or directory
# dos2unix: Skipping ./cfg/yolov3_custom_train.cfg, not a regular file.

# %%
# If your output cell shows something similar like belows, then congratulation, your model has started training successfully!
# %cd /content/drive/MyDrive/darknet
# !./darknet detector train /content/drive/MyDrive/darknet/cfg/coco.data /content/drive/MyDrive/yolococo/cfg/yolov3.cfg darknet53.conv.74
# Out:
# /content/drive/MyDrive/darknet
# yolov3
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
# ...

# %% [markdown]
# ## Train with pre-trained weight.

# %%
# copy pre-trained weight from your Drive to folder darknet
# !cp /content/drive/MyDrive/yolococo/cfg/yolov3.weights /content/darknet

# train annd save loss result in log.txt
# %cd /content/darknet
# !./darknet detector train /content/drive/MyDrive/darknet/cfg/coco.data /content/drive/MyDrive/yolococo/cfg/yolov3.cfg /content/drive/MyDrive/yolococo/cfg/yolov3.weights | tee log.txt
# Out:
# /content/darknet
# /bin/bash: ./darknet: No such file or directory

# %% [markdown]
# ## The End!
